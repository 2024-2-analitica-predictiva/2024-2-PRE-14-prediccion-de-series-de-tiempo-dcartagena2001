# %%
# =============================================================================
# Análisis básico - Mano de obra en un estado
# =============================================================================

# Carga de datos
import nbimporter  # Permite importar notebooks como módulos
import functions  # Asegúrate de que "functions.ipynb" esté disponible y correctamente configurado

# Cargar datos usando la función definida en "functions"
df_orig = functions.load_data()

# Mostrar las primeras filas del DataFrame y sus dimensiones
display(df_orig.head())  # Muestra las primeras filas del DataFrame
display(df_orig.shape)   # Muestra las dimensiones del DataFrame (filas, columnas)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 10
#       7 import functions  # Asegúrate de que "functions.ipynb" esté disponible y correctamente configurado
#       9 # Cargar datos usando la función definida en "functions"
# ---> 10 df_orig = functions.load_data()
#      12 # Mostrar las primeras filas del DataFrame y sus dimensiones
#      13 display(df_orig.head())  # Muestra las primeras filas del DataFrame
#
# AttributeError: module 'functions' has no attribute 'load_data'

# %%
#
# Grafico de la serie
# La serie correspondiente al número total de personas empleadas
# mensualmente como mano de obra en el condado de Sutter
# (California) entre 1946:01 y 1966:12. Se deben usar los primeros
# 228 (de 1946:1 a 1964:12) datos para especificar el modelo y los
# 24 datos restantes (1965:1 a 1966:12) para evaluar el pronóstico
# un mes adelante por fuera de la muestra de calibración de
# los parámetros.
#
functions.plot_time_series(df_orig)

# %%
#
# Autocorrelograma simple
#
functions.acf_pacf_plots(df_orig.yt_true)
